# %%
# IMplementing a Market Basket Analysis using the Apriori Algorithm
# https://www.geeksforgeeks.org/apriori-algorithm/
# https://en.wikipedia.org/wiki/Apriori_algorithm

# read transactions
df_groceries <- read.csv("C:/Users/kgtrm/Documents/R projects data/Groceries_dataset.csv")
str(df_groceries)
# Out:
# 'data.frame':	38765 obs. of  3 variables:
#  $ Member_number  : int  1808 2552 2300 1187 3037 4941 4501 3803 2762 4119 ...
#  $ Date           : chr  "21-07-2015" "05-01-2015" "19-09-2015" "12-12-2015" ...
#  $ itemDescription: chr  "tropical fruit" "whole milk" "pip fruit" "other vegetables" ...

# %%
df_sorted <- df_groceries[order(df_groceries$Member_number),]

# %%
# convert member number to numeric and item description to categorical
df_sorted$Member_number <- as.numeric(df_sorted$Member_number)

df_sorted$itemDescription <- as.factor(df_sorted$itemDescription)

str(df_sorted)
# Out:
# 'data.frame':	38765 obs. of  3 variables:
#  $ Member_number  : num  1000 1000 1000 1000 1000 1000 1000 1000 1000 1000 ...
#  $ Date           : chr  "27-05-2015" "24-07-2015" "15-03-2015" "25-11-2015" ...
#  $ itemDescription: Factor w/ 167 levels "abrasive cleaner",..: 138 19 130 130 165 165 108 92 132 72 ...

# %%
# convert dataframe to transaction format using ddply
# first need to unload a package

if(sessionInfo()['basePkgs']=="dplyr" | sessionInfo()['otherPkgs']=="dplyr") {
    detach(package:dplyr, unload = TRUE)
}

# %%
# group all items that were brought together
# by same customer on the same date
library(plyr)

# %%
df_itemList <- ddply(df_groceries, c("Member_number", "Date"), function(df1)paste(df1$itemDescription, collapse = ","))
str(df_itemList)
# Out:
# 'data.frame':	14963 obs. of  3 variables:
#  $ Member_number: int  1000 1000 1000 1000 1000 1001 1001 1001 1001 1001 ...
#  $ Date         : chr  "15-03-2015" "24-06-2014" "24-07-2015" "25-11-2015" ...
#  $ V1           : chr  "sausage,whole milk,semi-finished bread,yogurt" "whole milk,pastry,salty snack" "canned beer,misc. beverages" "sausage,hygiene articles" ...

# %%
# remove member number and date
df_itemList$Member_number <- NULL
df_itemList$Date <- NULL
str(df_itemList)
# Out:
# 'data.frame':	14963 obs. of  1 variable:
#  $ V1: chr  "sausage,whole milk,semi-finished bread,yogurt" "whole milk,pastry,salty snack" "canned beer,misc. beverages" "sausage,hygiene articles" ...

# %%
colnames(df_itemList) <- c("itemList")

# %%
# write to csv format
write.csv(df_itemList, "C:/Users/kgtrm/Documents/R projects data/ItemList.csv",
         quote = FALSE, row.names = TRUE)

# %%
# association rule mining algorithm: apriori
# the idea is we find the groups that occur often
# e.g., people buy milk, eggs, and butter together frequently
library(arules)
# Out:
# Loading required package: Matrix
#
#
# Attaching package: 'arules'
#
#
# The following objects are masked from 'package:base':
#
#     abbreviate, write

# %%
# convert the csv file to basket format
txn <- read.transactions(file = "C:/Users/kgtrm/Documents/R projects data/ItemList.csv",
                        rm.duplicates = FALSE, format = "basket", sep = ",", cols = 1)
str(txn)
# Out:
# Warning message in asMethod(object):
# "removing duplicated items in transactions"
# Formal class 'transactions' [package "arules"] with 3 slots
#   ..@ data       :Formal class 'ngCMatrix' [package "Matrix"] with 5 slots
#   .. .. ..@ i       : int [1:38007] 75 130 132 165 166 105 128 165 18 92 ...
#   .. .. ..@ p       : int [1:14965] 0 1 5 8 10 12 14 16 19 21 ...
#   .. .. ..@ Dim     : int [1:2] 168 14964
#   .. .. ..@ Dimnames:List of 2
#   .. .. .. ..$ : NULL
#   .. .. .. ..$ : NULL
#   .. .. ..@ factors : list()
#   ..@ itemInfo   :'data.frame':	168 obs. of  1 variable:
#   .. ..$ labels: chr [1:168] "abrasive cleaner" "artif. sweetener" "baby cosmetics" "bags" ...
#   ..@ itemsetInfo:'data.frame':	14964 obs. of  1 variable:
#   .. ..$ transactionID: chr [1:14964] "" "1" "2" "3" ...

# %%
# remove '\"' and '""' from the transactions 
txn@itemInfo$labels <- gsub("\"", "", txn@itemInfo$labels)

# %%
# run the apriori algorithm
basket_rules <- apriori(txn, 
                        parameter = list(minlen = 2, 
                                         sup = 0.001,
                                         conf = 0.01,
                                         target = "rules"))
# basket_rules <- apriori(txn, 
#                         parameter = list(minlen = 2, 
#                                          sup = 0.00001,
#                                          conf = 0.01,
#                                          target = "rules"),
#                         appearance = list(lhs = "CLEMENTINES"))
# Out:
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#        0.01    0.1    1 none FALSE            TRUE       5   0.001      2
#  maxlen target  ext
#      10  rules TRUE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[168 item(s), 14964 transaction(s)] done [0.00s].
# sorting and recoding items ... [149 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [1186 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].

# %%
# check if tm is attached, if yes, then detach
if(sessionInfo()['basePkgs']=="tm" | sessionInfo()['otherPkgs']=="tm"){
  detach(package:sentiment, unload=TRUE)
  detach(package:tm, unload=TRUE)
}

# %%
# view the rules
inspect(basket_rules)
# Out:
#        lhs                              rhs                         support
# [1]    {frozen fish}                 => {whole milk}                0.001069233
# [2]    {seasonal products}           => {rolls/buns}                0.001002406
# [3]    {pot plants}                  => {other vegetables}          0.001002406
# [4]    {pot plants}                  => {whole milk}                0.001002406
# [5]    {pasta}                       => {whole milk}                0.001069233
# [6]    {pickled vegetables}          => {whole milk}                0.001002406
# [7]    {packaged fruit/vegetables}   => {rolls/buns}                0.001202887
# [8]    {rolls/buns}                  => {packaged fruit/vegetables} 0.001202887
# [9]    {detergent}                   => {yogurt}                    0.001069233
# [10]   {yogurt}                      => {detergent}                 0.001069233
# [11]   {detergent}                   => {rolls/buns}                0.001002406
# [12]   {detergent}                   => {whole milk}                0.001403368
# [13]   {semi-finished bread}         => {other vegetables}          0.001002406
# [14]   {semi-finished bread}         => {whole milk}                0.001670676
# [15]   {whole milk}                  => {semi-finished bread}       0.001670676
# [16]   {red/blush wine}              => {rolls/buns}                0.001336541
# [17]   {rolls/buns}                  => {red/blush wine}            0.001336541
# [18]   {red/blush wine}              => {other vegetables}          0.001136060
# [19]   {flour}                       => {tropical fruit}            0.001069233
# [20]   {tropical fruit}              => {flour}                     0.001069233
# [21]   {flour}                       => {whole milk}                0.001336541
# [22]   {herbs}                       => {yogurt}                    0.001136060
# [23]   {yogurt}                      => {herbs}                     0.001136060
# [24]   {herbs}                       => {whole milk}                0.001136060
# [25]   {processed cheese}            => {root vegetables}           0.001069233
# [26]   {root vegetables}             => {processed cheese}          0.001069233
# [27]   {processed cheese}            => {rolls/buns}                0.001470195
# [28]   {rolls/buns}                  => {processed cheese}          0.001470195
# [29]   {processed cheese}            => {whole milk}                0.001470195
# [30]   {soft cheese}                 => {yogurt}                    0.001269714
# [31]   {yogurt}                      => {soft cheese}               0.001269714
# [32]   {soft cheese}                 => {rolls/buns}                0.001002406
# [33]   {soft cheese}                 => {other vegetables}          0.001202887
# [34]   {soft cheese}                 => {whole milk}                0.001202887
# [35]   {white wine}                  => {whole milk}                0.001269714
# [36]   {cat food}                    => {tropical fruit}            0.001002406
# [37]   {tropical fruit}              => {cat food}                  0.001002406
# [38]   {cat food}                    => {rolls/buns}                0.001069233
# [39]   {cat food}                    => {whole milk}                0.001670676
# [40]   {whole milk}                  => {cat food}                  0.001670676
# [41]   {chewing gum}                 => {yogurt}                    0.001403368
# [42]   {yogurt}                      => {chewing gum}               0.001403368
# [43]   {chewing gum}                 => {soda}                      0.001002406
# [44]   {soda}                        => {chewing gum}               0.001002406
# [45]   {chewing gum}                 => {other vegetables}          0.001069233
# [46]   {chewing gum}                 => {whole milk}                0.001670676
# [47]   {whole milk}                  => {chewing gum}               0.001670676
# [48]   {specialty bar}               => {yogurt}                    0.001202887
# [49]   {yogurt}                      => {specialty bar}             0.001202887
# [50]   {specialty bar}               => {soda}                      0.001269714
# [51]   {soda}                        => {specialty bar}             0.001269714
# [52]   {specialty bar}               => {rolls/buns}                0.001202887
# [53]   {rolls/buns}                  => {specialty bar}             0.001202887
# [54]   {specialty bar}               => {other vegetables}          0.001670676
# [55]   {other vegetables}            => {specialty bar}             0.001670676
# [56]   {specialty bar}               => {whole milk}                0.001670676
# [57]   {whole milk}                  => {specialty bar}             0.001670676
# [58]   {hygiene articles}            => {root vegetables}           0.001002406
# [59]   {root vegetables}             => {hygiene articles}          0.001002406
# [60]   {hygiene articles}            => {soda}                      0.001069233
# [61]   {soda}                        => {hygiene articles}          0.001069233
# [62]   {hygiene articles}            => {rolls/buns}                0.001336541
# [63]   {rolls/buns}                  => {hygiene articles}          0.001336541
# [64]   {hygiene articles}            => {other vegetables}          0.001403368
# [65]   {other vegetables}            => {hygiene articles}          0.001403368
# [66]   {hygiene articles}            => {whole milk}                0.001737503
# [67]   {whole milk}                  => {hygiene articles}          0.001737503
# [68]   {candy}                       => {citrus fruit}              0.001002406
# [69]   {citrus fruit}                => {candy}                     0.001002406
# [70]   {candy}                       => {yogurt}                    0.001202887
# [71]   {yogurt}                      => {candy}                     0.001202887
# [72]   {candy}                       => {soda}                      0.001269714
# [73]   {soda}                        => {candy}                     0.001269714
# [74]   {candy}                       => {rolls/buns}                0.001470195
# [75]   {rolls/buns}                  => {candy}                     0.001470195
# [76]   {candy}                       => {other vegetables}          0.001136060
# [77]   {candy}                       => {whole milk}                0.002138466
# [78]   {whole milk}                  => {candy}                     0.002138466
# [79]   {sliced cheese}               => {sausage}                   0.001136060
# [80]   {sausage}                     => {sliced cheese}             0.001136060
# [81]   {sliced cheese}               => {root vegetables}           0.001202887
# [82]   {root vegetables}             => {sliced cheese}             0.001202887
# [83]   {sliced cheese}               => {soda}                      0.001136060
# [84]   {soda}                        => {sliced cheese}             0.001136060
# [85]   {sliced cheese}               => {other vegetables}          0.001403368
# [86]   {other vegetables}            => {sliced cheese}             0.001403368
# [87]   {sliced cheese}               => {whole milk}                0.001470195
# [88]   {ice cream}                   => {soda}                      0.001202887
# [89]   {soda}                        => {ice cream}                 0.001202887
# [90]   {ice cream}                   => {rolls/buns}                0.001737503
# [91]   {rolls/buns}                  => {ice cream}                 0.001737503
# [92]   {ice cream}                   => {other vegetables}          0.001269714
# [93]   {other vegetables}            => {ice cream}                 0.001269714
# [94]   {ice cream}                   => {whole milk}                0.001937984
# [95]   {whole milk}                  => {ice cream}                 0.001937984
# [96]   {grapes}                      => {sausage}                   0.001069233
# [97]   {sausage}                     => {grapes}                    0.001069233
# [98]   {grapes}                      => {root vegetables}           0.001069233
# [99]   {root vegetables}             => {grapes}                    0.001069233
# [100]  {grapes}                      => {soda}                      0.001403368
# [101]  {soda}                        => {grapes}                    0.001403368
# [102]  {grapes}                      => {rolls/buns}                0.001202887
# [103]  {rolls/buns}                  => {grapes}                    0.001202887
# [104]  {grapes}                      => {other vegetables}          0.001603849
# [105]  {other vegetables}            => {grapes}                    0.001603849
# [106]  {grapes}                      => {whole milk}                0.001937984
# [107]  {whole milk}                  => {grapes}                    0.001937984
# [108]  {oil}                         => {yogurt}                    0.001069233
# [109]  {yogurt}                      => {oil}                       0.001069233
# [110]  {oil}                         => {soda}                      0.001804330
# [111]  {soda}                        => {oil}                       0.001804330
# [112]  {oil}                         => {rolls/buns}                0.001336541
# [113]  {rolls/buns}                  => {oil}                       0.001336541
# [114]  {oil}                         => {other vegetables}          0.001804330
# [115]  {other vegetables}            => {oil}                       0.001804330
# [116]  {oil}                         => {whole milk}                0.001937984
# [117]  {whole milk}                  => {oil}                       0.001937984
# [118]  {misc. beverages}             => {sausage}                   0.001069233
# [119]  {sausage}                     => {misc. beverages}           0.001069233
# [120]  {misc. beverages}             => {root vegetables}           0.001002406
# [121]  {root vegetables}             => {misc. beverages}           0.001002406
# [122]  {misc. beverages}             => {yogurt}                    0.001269714
# [123]  {yogurt}                      => {misc. beverages}           0.001269714
# [124]  {misc. beverages}             => {rolls/buns}                0.001336541
# [125]  {rolls/buns}                  => {misc. beverages}           0.001336541
# [126]  {misc. beverages}             => {other vegetables}          0.001202887
# [127]  {misc. beverages}             => {whole milk}                0.001403368
# [128]  {hard cheese}                 => {pip fruit}                 0.001069233
# [129]  {pip fruit}                   => {hard cheese}               0.001069233
# [130]  {hard cheese}                 => {root vegetables}           0.001002406
# [131]  {root vegetables}             => {hard cheese}               0.001002406
# [132]  {hard cheese}                 => {yogurt}                    0.001269714
# [133]  {yogurt}                      => {hard cheese}               0.001269714
# [134]  {hard cheese}                 => {rolls/buns}                0.001670676
# [135]  {rolls/buns}                  => {hard cheese}               0.001670676
# [136]  {hard cheese}                 => {other vegetables}          0.001670676
# [137]  {other vegetables}            => {hard cheese}               0.001670676
# [138]  {hard cheese}                 => {whole milk}                0.001871157
# [139]  {whole milk}                  => {hard cheese}               0.001871157
# [140]  {specialty chocolate}         => {citrus fruit}              0.001403368
# [141]  {citrus fruit}                => {specialty chocolate}       0.001403368
# [142]  {specialty chocolate}         => {tropical fruit}            0.001336541
# [143]  {tropical fruit}              => {specialty chocolate}       0.001336541
# [144]  {specialty chocolate}         => {soda}                      0.001403368
# [145]  {soda}                        => {specialty chocolate}       0.001403368
# [146]  {specialty chocolate}         => {rolls/buns}                0.001269714
# [147]  {rolls/buns}                  => {specialty chocolate}       0.001269714
# [148]  {specialty chocolate}         => {other vegetables}          0.001670676
# [149]  {other vegetables}            => {specialty chocolate}       0.001670676
# [150]  {specialty chocolate}         => {whole milk}                0.001336541
# [151]  {meat}                        => {root vegetables}           0.001336541
# [152]  {root vegetables}             => {meat}                      0.001336541
# [153]  {meat}                        => {soda}                      0.001002406
# [154]  {soda}                        => {meat}                      0.001002406
# [155]  {meat}                        => {rolls/buns}                0.001336541
# [156]  {rolls/buns}                  => {meat}                      0.001336541
# [157]  {meat}                        => {other vegetables}          0.002138466
# [158]  {other vegetables}            => {meat}                      0.002138466
# [159]  {meat}                        => {whole milk}                0.002205293
# [160]  {whole milk}                  => {meat}                      0.002205293
# [161]  {beverages}                   => {bottled water}             0.001069233
# [162]  {bottled water}               => {beverages}                 0.001069233
# [163]  {beverages}                   => {sausage}                   0.001537022
# [164]  {sausage}                     => {beverages}                 0.001537022
# [165]  {beverages}                   => {soda}                      0.001871157
# [166]  {soda}                        => {beverages}                 0.001871157
# [167]  {beverages}                   => {rolls/buns}                0.001202887
# [168]  {rolls/buns}                  => {beverages}                 0.001202887
# [169]  {beverages}                   => {other vegetables}          0.001737503
# [170]  {other vegetables}            => {beverages}                 0.001737503
# [171]  {beverages}                   => {whole milk}                0.001937984
# [172]  {whole milk}                  => {beverages}                 0.001937984
# [173]  {ham}                         => {tropical fruit}            0.001136060
# [174]  {tropical fruit}              => {ham}                       0.001136060
# [175]  {ham}                         => {yogurt}                    0.001269714
# [176]  {yogurt}                      => {ham}                       0.001269714
# [177]  {ham}                         => {soda}                      0.001202887
# [178]  {soda}                        => {ham}                       0.001202887
# [179]  {ham}                         => {rolls/buns}                0.001269714
# [180]  {rolls/buns}                  => {ham}                       0.001269714
# [181]  {ham}                         => {other vegetables}          0.001603849
# [182]  {other vegetables}            => {ham}                       0.001603849
# [183]  {ham}                         => {whole milk}                0.002739909
# [184]  {whole milk}                  => {ham}                       0.002739909
# [185]  {frozen meals}                => {sausage}                   0.001269714
# [186]  {sausage}                     => {frozen meals}              0.001269714
# [187]  {frozen meals}                => {yogurt}                    0.001336541
# [188]  {yogurt}                      => {frozen meals}              0.001336541
# [189]  {frozen meals}                => {soda}                      0.001537022
# [190]  {soda}                        => {frozen meals}              0.001537022
# [191]  {frozen meals}                => {rolls/buns}                0.001470195
# [192]  {rolls/buns}                  => {frozen meals}              0.001470195
# [193]  {frozen meals}                => {other vegetables}          0.002138466
# [194]  {other vegetables}            => {frozen meals}              0.002138466
# [195]  {frozen meals}                => {whole milk}                0.001937984
# [196]  {whole milk}                  => {frozen meals}              0.001937984
# [197]  {butter milk}                 => {shopping bags}             0.001002406
# [198]  {shopping bags}               => {butter milk}               0.001002406
# [199]  {butter milk}                 => {root vegetables}           0.001002406
# [200]  {root vegetables}             => {butter milk}               0.001002406
# [201]  {butter milk}                 => {tropical fruit}            0.001002406
# [202]  {tropical fruit}              => {butter milk}               0.001002406
# [203]  {butter milk}                 => {yogurt}                    0.001269714
# [204]  {yogurt}                      => {butter milk}               0.001269714
# [205]  {butter milk}                 => {soda}                      0.001403368
# [206]  {soda}                        => {butter milk}               0.001403368
# [207]  {butter milk}                 => {rolls/buns}                0.001269714
# [208]  {rolls/buns}                  => {butter milk}               0.001269714
# [209]  {butter milk}                 => {other vegetables}          0.001269714
# [210]  {other vegetables}            => {butter milk}               0.001269714
# [211]  {butter milk}                 => {whole milk}                0.001670676
# [212]  {whole milk}                  => {butter milk}               0.001670676
# [213]  {sugar}                       => {bottled water}             0.001470195
# [214]  {bottled water}               => {sugar}                     0.001470195
# [215]  {sugar}                       => {tropical fruit}            0.001002406
# [216]  {tropical fruit}              => {sugar}                     0.001002406
# [217]  {sugar}                       => {soda}                      0.001202887
# [218]  {soda}                        => {sugar}                     0.001202887
# [219]  {sugar}                       => {other vegetables}          0.001269714
# [220]  {other vegetables}            => {sugar}                     0.001269714
# [221]  {sugar}                       => {whole milk}                0.002472601
# [222]  {whole milk}                  => {sugar}                     0.002472601
# [223]  {long life bakery product}    => {sausage}                   0.001069233
# [224]  {sausage}                     => {long life bakery product}  0.001069233
# [225]  {long life bakery product}    => {tropical fruit}            0.001069233
# [226]  {tropical fruit}              => {long life bakery product}  0.001069233
# [227]  {long life bakery product}    => {yogurt}                    0.001202887
# [228]  {yogurt}                      => {long life bakery product}  0.001202887
# [229]  {long life bakery product}    => {soda}                      0.001336541
# [230]  {soda}                        => {long life bakery product}  0.001336541
# [231]  {long life bakery product}    => {rolls/buns}                0.001670676
# [232]  {rolls/buns}                  => {long life bakery product}  0.001670676
# [233]  {long life bakery product}    => {other vegetables}          0.001136060
# [234]  {long life bakery product}    => {whole milk}                0.002405774
# [235]  {whole milk}                  => {long life bakery product}  0.002405774
# [236]  {waffles}                     => {root vegetables}           0.001336541
# [237]  {root vegetables}             => {waffles}                   0.001336541
# [238]  {waffles}                     => {tropical fruit}            0.001136060
# [239]  {tropical fruit}              => {waffles}                   0.001136060
# [240]  {waffles}                     => {yogurt}                    0.001136060
# [241]  {yogurt}                      => {waffles}                   0.001136060
# [242]  {waffles}                     => {rolls/buns}                0.001603849
# [243]  {rolls/buns}                  => {waffles}                   0.001603849
# [244]  {waffles}                     => {other vegetables}          0.001737503
# [245]  {other vegetables}            => {waffles}                   0.001737503
# [246]  {waffles}                     => {whole milk}                0.002606255
# [247]  {whole milk}                  => {waffles}                   0.002606255
# [248]  {salty snack}                 => {canned beer}               0.001002406
# [249]  {canned beer}                 => {salty snack}               0.001002406
# [250]  {salty snack}                 => {sausage}                   0.001136060
# [251]  {sausage}                     => {salty snack}               0.001136060
# [252]  {salty snack}                 => {root vegetables}           0.001069233
# [253]  {root vegetables}             => {salty snack}               0.001069233
# [254]  {salty snack}                 => {tropical fruit}            0.001002406
# [255]  {tropical fruit}              => {salty snack}               0.001002406
# [256]  {salty snack}                 => {yogurt}                    0.001537022
# [257]  {yogurt}                      => {salty snack}               0.001537022
# [258]  {salty snack}                 => {soda}                      0.001403368
# [259]  {soda}                        => {salty snack}               0.001403368
# [260]  {salty snack}                 => {rolls/buns}                0.001937984
# [261]  {rolls/buns}                  => {salty snack}               0.001937984
# [262]  {salty snack}                 => {other vegetables}          0.002205293
# [263]  {other vegetables}            => {salty snack}               0.002205293
# [264]  {salty snack}                 => {whole milk}                0.001937984
# [265]  {whole milk}                  => {salty snack}               0.001937984
# [266]  {onions}                      => {whipped/sour cream}        0.001069233
# [267]  {whipped/sour cream}          => {onions}                    0.001069233
# [268]  {onions}                      => {bottled water}             0.001002406
# [269]  {bottled water}               => {onions}                    0.001002406
# [270]  {onions}                      => {root vegetables}           0.001336541
# [271]  {root vegetables}             => {onions}                    0.001336541
# [272]  {onions}                      => {tropical fruit}            0.001202887
# [273]  {tropical fruit}              => {onions}                    0.001202887
# [274]  {onions}                      => {yogurt}                    0.001269714
# [275]  {yogurt}                      => {onions}                    0.001269714
# [276]  {onions}                      => {soda}                      0.001470195
# [277]  {soda}                        => {onions}                    0.001470195
# [278]  {onions}                      => {rolls/buns}                0.001737503
# [279]  {rolls/buns}                  => {onions}                    0.001737503
# [280]  {onions}                      => {other vegetables}          0.001537022
# [281]  {other vegetables}            => {onions}                    0.001537022
# [282]  {onions}                      => {whole milk}                0.002940390
# [283]  {whole milk}                  => {onions}                    0.002940390
# [284]  {UHT-milk}                    => {bottled water}             0.001069233
# [285]  {bottled water}               => {UHT-milk}                  0.001069233
# [286]  {UHT-milk}                    => {sausage}                   0.001136060
# [287]  {sausage}                     => {UHT-milk}                  0.001136060
# [288]  {UHT-milk}                    => {root vegetables}           0.001002406
# [289]  {root vegetables}             => {UHT-milk}                  0.001002406
# [290]  {UHT-milk}                    => {tropical fruit}            0.001537022
# [291]  {tropical fruit}              => {UHT-milk}                  0.001537022
# [292]  {UHT-milk}                    => {yogurt}                    0.001136060
# [293]  {yogurt}                      => {UHT-milk}                  0.001136060
# [294]  {UHT-milk}                    => {soda}                      0.001269714
# [295]  {soda}                        => {UHT-milk}                  0.001269714
# [296]  {UHT-milk}                    => {rolls/buns}                0.001804330
# [297]  {rolls/buns}                  => {UHT-milk}                  0.001804330
# [298]  {UHT-milk}                    => {other vegetables}          0.002138466
# [299]  {other vegetables}            => {UHT-milk}                  0.002138466
# [300]  {UHT-milk}                    => {whole milk}                0.002539428
# [301]  {whole milk}                  => {UHT-milk}                  0.002539428
# [302]  {berries}                     => {pip fruit}                 0.001136060
# [303]  {pip fruit}                   => {berries}                   0.001136060
# [304]  {berries}                     => {pastry}                    0.001069233
# [305]  {pastry}                      => {berries}                   0.001069233
# [306]  {berries}                     => {bottled water}             0.001069233
# [307]  {bottled water}               => {berries}                   0.001069233
# [308]  {berries}                     => {root vegetables}           0.001069233
# [309]  {root vegetables}             => {berries}                   0.001069233
# [310]  {berries}                     => {tropical fruit}            0.001269714
# [311]  {tropical fruit}              => {berries}                   0.001269714
# [312]  {berries}                     => {yogurt}                    0.001403368
# [313]  {yogurt}                      => {berries}                   0.001403368
# [314]  {berries}                     => {soda}                      0.001470195
# [315]  {soda}                        => {berries}                   0.001470195
# [316]  {berries}                     => {rolls/buns}                0.001670676
# [317]  {rolls/buns}                  => {berries}                   0.001670676
# [318]  {berries}                     => {other vegetables}          0.002673082
# [319]  {other vegetables}            => {berries}                   0.002673082
# [320]  {berries}                     => {whole milk}                0.002272120
# [321]  {whole milk}                  => {berries}                   0.002272120
# [322]  {hamburger meat}              => {bottled beer}              0.001069233
# [323]  {bottled beer}                => {hamburger meat}            0.001069233
# [324]  {hamburger meat}              => {pastry}                    0.001002406
# [325]  {pastry}                      => {hamburger meat}            0.001002406
# [326]  {hamburger meat}              => {root vegetables}           0.001269714
# [327]  {root vegetables}             => {hamburger meat}            0.001269714
# [328]  {hamburger meat}              => {tropical fruit}            0.001336541
# [329]  {tropical fruit}              => {hamburger meat}            0.001336541
# [330]  {hamburger meat}              => {yogurt}                    0.001670676
# [331]  {yogurt}                      => {hamburger meat}            0.001670676
# [332]  {hamburger meat}              => {soda}                      0.001670676
# [333]  {soda}                        => {hamburger meat}            0.001670676
# [334]  {hamburger meat}              => {rolls/buns}                0.001937984
# [335]  {rolls/buns}                  => {hamburger meat}            0.001937984
# [336]  {hamburger meat}              => {other vegetables}          0.002205293
# [337]  {other vegetables}            => {hamburger meat}            0.002205293
# [338]  {hamburger meat}              => {whole milk}                0.003074044
# [339]  {whole milk}                  => {hamburger meat}            0.003074044
# [340]  {dessert}                     => {curd}                      0.001002406
# [341]  {curd}                        => {dessert}                   0.001002406
# [342]  {dessert}                     => {shopping bags}             0.001202887
# [343]  {shopping bags}               => {dessert}                   0.001202887
# [344]  {dessert}                     => {bottled water}             0.001069233
# [345]  {bottled water}               => {dessert}                   0.001069233
# [346]  {dessert}                     => {sausage}                   0.001470195
# [347]  {sausage}                     => {dessert}                   0.001470195
# [348]  {dessert}                     => {root vegetables}           0.001069233
# [349]  {root vegetables}             => {dessert}                   0.001069233
# [350]  {dessert}                     => {tropical fruit}            0.001069233
# [351]  {tropical fruit}              => {dessert}                   0.001069233
# [352]  {dessert}                     => {yogurt}                    0.001202887
# [353]  {yogurt}                      => {dessert}                   0.001202887
# [354]  {dessert}                     => {soda}                      0.001470195
# [355]  {soda}                        => {dessert}                   0.001470195
# [356]  {dessert}                     => {rolls/buns}                0.002004812
# [357]  {rolls/buns}                  => {dessert}                   0.002004812
# [358]  {dessert}                     => {other vegetables}          0.002071639
# [359]  {other vegetables}            => {dessert}                   0.002071639
# [360]  {dessert}                     => {whole milk}                0.002405774
# [361]  {whole milk}                  => {dessert}                   0.002405774
# [362]  {napkins}                     => {pastry}                    0.001737503
# [363]  {pastry}                      => {napkins}                   0.001737503
# [364]  {napkins}                     => {citrus fruit}              0.001403368
# [365]  {citrus fruit}                => {napkins}                   0.001403368
# [366]  {napkins}                     => {root vegetables}           0.001069233
# [367]  {root vegetables}             => {napkins}                   0.001069233
# [368]  {napkins}                     => {tropical fruit}            0.001269714
# [369]  {tropical fruit}              => {napkins}                   0.001269714
# [370]  {napkins}                     => {yogurt}                    0.001737503
# [371]  {yogurt}                      => {napkins}                   0.001737503
# [372]  {napkins}                     => {soda}                      0.001537022
# [373]  {soda}                        => {napkins}                   0.001537022
# [374]  {napkins}                     => {rolls/buns}                0.001737503
# [375]  {rolls/buns}                  => {napkins}                   0.001737503
# [376]  {napkins}                     => {other vegetables}          0.002138466
# [377]  {other vegetables}            => {napkins}                   0.002138466
# [378]  {napkins}                     => {whole milk}                0.002405774
# [379]  {whole milk}                  => {napkins}                   0.002405774
# [380]  {cream cheese}                => {frankfurter}               0.001002406
# [381]  {frankfurter}                 => {cream cheese}              0.001002406
# [382]  {cream cheese}                => {shopping bags}             0.001202887
# [383]  {shopping bags}               => {cream cheese}              0.001202887
# [384]  {cream cheese}                => {citrus fruit}              0.001002406
# [385]  {citrus fruit}                => {cream cheese}              0.001002406
# [386]  {cream cheese}                => {sausage}                   0.001202887
# [387]  {sausage}                     => {cream cheese}              0.001202887
# [388]  {cream cheese}                => {root vegetables}           0.001603849
# [389]  {root vegetables}             => {cream cheese}              0.001603849
# [390]  {cream cheese}                => {tropical fruit}            0.001403368
# [391]  {tropical fruit}              => {cream cheese}              0.001403368
# [392]  {cream cheese}                => {yogurt}                    0.001603849
# [393]  {yogurt}                      => {cream cheese}              0.001603849
# [394]  {cream cheese}                => {soda}                      0.001470195
# [395]  {soda}                        => {cream cheese}              0.001470195
# [396]  {cream cheese}                => {rolls/buns}                0.001871157
# [397]  {rolls/buns}                  => {cream cheese}              0.001871157
# [398]  {cream cheese}                => {other vegetables}          0.002138466
# [399]  {other vegetables}            => {cream cheese}              0.002138466
# [400]  {cream cheese}                => {whole milk}                0.002873563
# [401]  {whole milk}                  => {cream cheese}              0.002873563
# [402]  {chocolate}                   => {bottled beer}              0.001002406
# [403]  {bottled beer}                => {chocolate}                 0.001002406
# [404]  {chocolate}                   => {canned beer}               0.001069233
# [405]  {canned beer}                 => {chocolate}                 0.001069233
# [406]  {chocolate}                   => {pip fruit}                 0.001336541
# [407]  {pip fruit}                   => {chocolate}                 0.001336541
# [408]  {chocolate}                   => {citrus fruit}              0.001069233
# [409]  {citrus fruit}                => {chocolate}                 0.001069233
# [410]  {chocolate}                   => {bottled water}             0.001403368
# [411]  {bottled water}               => {chocolate}                 0.001403368
# [412]  {chocolate}                   => {sausage}                   0.001403368
# [413]  {sausage}                     => {chocolate}                 0.001403368
# [414]  {chocolate}                   => {root vegetables}           0.001202887
# [415]  {root vegetables}             => {chocolate}                 0.001202887
# [416]  {chocolate}                   => {tropical fruit}            0.001403368
# [417]  {tropical fruit}              => {chocolate}                 0.001403368
# [418]  {chocolate}                   => {yogurt}                    0.001603849
# [419]  {yogurt}                      => {chocolate}                 0.001603849
# [420]  {chocolate}                   => {soda}                      0.001670676
# [421]  {soda}                        => {chocolate}                 0.001670676
# [422]  {chocolate}                   => {rolls/buns}                0.002806736
# [423]  {rolls/buns}                  => {chocolate}                 0.002806736
# [424]  {chocolate}                   => {other vegetables}          0.001871157
# [425]  {other vegetables}            => {chocolate}                 0.001871157
# [426]  {chocolate}                   => {whole milk}                0.002940390
# [427]  {whole milk}                  => {chocolate}                 0.002940390
# [428]  {white bread}                 => {domestic eggs}             0.001002406
# [429]  {domestic eggs}               => {white bread}               0.001002406
# [430]  {white bread}                 => {brown bread}               0.001002406
# [431]  {brown bread}                 => {white bread}               0.001002406
# [432]  {white bread}                 => {whipped/sour cream}        0.001002406
# [433]  {whipped/sour cream}          => {white bread}               0.001002406
# [434]  {white bread}                 => {canned beer}               0.001537022
# [435]  {canned beer}                 => {white bread}               0.001537022
# [436]  {white bread}                 => {citrus fruit}              0.001136060
# [437]  {citrus fruit}                => {white bread}               0.001136060
# [438]  {white bread}                 => {bottled water}             0.001269714
# [439]  {bottled water}               => {white bread}               0.001269714
# [440]  {white bread}                 => {sausage}                   0.001403368
# [441]  {sausage}                     => {white bread}               0.001403368
# [442]  {white bread}                 => {root vegetables}           0.001269714
# [443]  {root vegetables}             => {white bread}               0.001269714
# [444]  {white bread}                 => {tropical fruit}            0.001002406
# [445]  {tropical fruit}              => {white bread}               0.001002406
# [446]  {white bread}                 => {yogurt}                    0.001069233
# [447]  {yogurt}                      => {white bread}               0.001069233
# [448]  {white bread}                 => {soda}                      0.001537022
# [449]  {soda}                        => {white bread}               0.001537022
# [450]  {white bread}                 => {rolls/buns}                0.002138466
# [451]  {rolls/buns}                  => {white bread}               0.002138466
# [452]  {white bread}                 => {other vegetables}          0.002606255
# [453]  {other vegetables}            => {white bread}               0.002606255
# [454]  {white bread}                 => {whole milk}                0.003140871
# [455]  {whole milk}                  => {white bread}               0.003140871
# [456]  {chicken}                     => {margarine}                 0.001002406
# [457]  {margarine}                   => {chicken}                   0.001002406
# [458]  {chicken}                     => {curd}                      0.001136060
# [459]  {curd}                        => {chicken}                   0.001136060
# [460]  {chicken}                     => {domestic eggs}             0.001002406
# [461]  {domestic eggs}               => {chicken}                   0.001002406
# [462]  {chicken}                     => {whipped/sour cream}        0.001269714
# [463]  {whipped/sour cream}          => {chicken}                   0.001269714
# [464]  {chicken}                     => {bottled beer}              0.001002406
# [465]  {bottled beer}                => {chicken}                   0.001002406
# [466]  {chicken}                     => {canned beer}               0.001136060
# [467]  {canned beer}                 => {chicken}                   0.001136060
# [468]  {chicken}                     => {shopping bags}             0.001269714
# [469]  {shopping bags}               => {chicken}                   0.001269714
# [470]  {chicken}                     => {pip fruit}                 0.001069233
# [471]  {pip fruit}                   => {chicken}                   0.001069233
# [472]  {chicken}                     => {pastry}                    0.001269714
# [473]  {pastry}                      => {chicken}                   0.001269714
# [474]  {chicken}                     => {citrus fruit}              0.001202887
# [475]  {citrus fruit}                => {chicken}                   0.001202887
# [476]  {chicken}                     => {bottled water}             0.001336541
# [477]  {bottled water}               => {chicken}                   0.001336541
# [478]  {chicken}                     => {sausage}                   0.001069233
# [479]  {sausage}                     => {chicken}                   0.001069233
# [480]  {chicken}                     => {root vegetables}           0.001002406
# [481]  {root vegetables}             => {chicken}                   0.001002406
# [482]  {chicken}                     => {tropical fruit}            0.001403368
# [483]  {tropical fruit}              => {chicken}                   0.001403368
# [484]  {chicken}                     => {yogurt}                    0.001804330
# [485]  {yogurt}                      => {chicken}                   0.001804330
# [486]  {chicken}                     => {soda}                      0.002138466
# [487]  {soda}                        => {chicken}                   0.002138466
# [488]  {chicken}                     => {rolls/buns}                0.002873563
# [489]  {rolls/buns}                  => {chicken}                   0.002873563
# [490]  {chicken}                     => {other vegetables}          0.002205293
# [491]  {other vegetables}            => {chicken}                   0.002205293
# [492]  {chicken}                     => {whole milk}                0.003408180
# [493]  {whole milk}                  => {chicken}                   0.003408180
# [494]  {frozen vegetables}           => {beef}                      0.001269714
# [495]  {beef}                        => {frozen vegetables}         0.001269714
# [496]  {frozen vegetables}           => {frankfurter}               0.001069233
# [497]  {frankfurter}                 => {frozen vegetables}         0.001069233
# [498]  {frozen vegetables}           => {bottled beer}              0.001403368
# [499]  {bottled beer}                => {frozen vegetables}         0.001403368
# [500]  {frozen vegetables}           => {canned beer}               0.001336541
# [501]  {canned beer}                 => {frozen vegetables}         0.001336541
# [502]  {frozen vegetables}           => {pip fruit}                 0.001336541
# [503]  {pip fruit}                   => {frozen vegetables}         0.001336541
# [504]  {frozen vegetables}           => {citrus fruit}              0.001603849
# [505]  {citrus fruit}                => {frozen vegetables}         0.001603849
# [506]  {frozen vegetables}           => {bottled water}             0.001069233
# [507]  {bottled water}               => {frozen vegetables}         0.001069233
# [508]  {frozen vegetables}           => {sausage}                   0.002071639
# [509]  {sausage}                     => {frozen vegetables}         0.002071639
# [510]  {frozen vegetables}           => {root vegetables}           0.002138466
# [511]  {root vegetables}             => {frozen vegetables}         0.002138466
# [512]  {frozen vegetables}           => {tropical fruit}            0.001069233
# [513]  {tropical fruit}              => {frozen vegetables}         0.001069233
# [514]  {frozen vegetables}           => {yogurt}                    0.002071639
# [515]  {yogurt}                      => {frozen vegetables}         0.002071639
# [516]  {frozen vegetables}           => {soda}                      0.002004812
# [517]  {soda}                        => {frozen vegetables}         0.002004812
# [518]  {frozen vegetables}           => {rolls/buns}                0.002739909
# [519]  {rolls/buns}                  => {frozen vegetables}         0.002739909
# [520]  {frozen vegetables}           => {other vegetables}          0.003140871
# [521]  {other vegetables}            => {frozen vegetables}         0.003140871
# [522]  {frozen vegetables}           => {whole milk}                0.003809142
# [523]  {whole milk}                  => {frozen vegetables}         0.003809142
# [524]  {coffee}                      => {domestic eggs}             0.001403368
# [525]  {domestic eggs}               => {coffee}                    0.001403368
# [526]  {coffee}                      => {frankfurter}               0.001470195
# [527]  {frankfurter}                 => {coffee}                    0.001470195
# [528]  {coffee}                      => {canned beer}               0.001002406
# [529]  {canned beer}                 => {coffee}                    0.001002406
# [530]  {coffee}                      => {shopping bags}             0.001403368
# [531]  {shopping bags}               => {coffee}                    0.001403368
# [532]  {coffee}                      => {pip fruit}                 0.001069233
# [533]  {pip fruit}                   => {coffee}                    0.001069233
# [534]  {coffee}                      => {pastry}                    0.001403368
# [535]  {pastry}                      => {coffee}                    0.001403368
# [536]  {coffee}                      => {citrus fruit}              0.001336541
# [537]  {citrus fruit}                => {coffee}                    0.001336541
# [538]  {coffee}                      => {bottled water}             0.001537022
# [539]  {bottled water}               => {coffee}                    0.001537022
# [540]  {coffee}                      => {sausage}                   0.001336541
# [541]  {sausage}                     => {coffee}                    0.001336541
# [542]  {coffee}                      => {root vegetables}           0.002004812
# [543]  {root vegetables}             => {coffee}                    0.002004812
# [544]  {coffee}                      => {tropical fruit}            0.001537022
# [545]  {tropical fruit}              => {coffee}                    0.001537022
# [546]  {coffee}                      => {yogurt}                    0.002071639
# [547]  {yogurt}                      => {coffee}                    0.002071639
# [548]  {coffee}                      => {soda}                      0.002472601
# [549]  {soda}                        => {coffee}                    0.002472601
# [550]  {coffee}                      => {rolls/buns}                0.002405774
# [551]  {rolls/buns}                  => {coffee}                    0.002405774
# [552]  {coffee}                      => {other vegetables}          0.002606255
# [553]  {other vegetables}            => {coffee}                    0.002606255
# [554]  {coffee}                      => {whole milk}                0.003809142
# [555]  {whole milk}                  => {coffee}                    0.003809142
# [556]  {margarine}                   => {beef}                      0.001403368
# [557]  {beef}                        => {margarine}                 0.001403368
# [558]  {margarine}                   => {fruit/vegetable juice}     0.001002406
# [559]  {fruit/vegetable juice}       => {margarine}                 0.001002406
# [560]  {margarine}                   => {curd}                      0.001069233
# [561]  {curd}                        => {margarine}                 0.001069233
# [562]  {margarine}                   => {butter}                    0.001403368
# [563]  {butter}                      => {margarine}                 0.001403368
# [564]  {margarine}                   => {pork}                      0.001336541
# [565]  {pork}                        => {margarine}                 0.001336541
# [566]  {margarine}                   => {frankfurter}               0.001603849
# [567]  {frankfurter}                 => {margarine}                 0.001603849
# [568]  {margarine}                   => {whipped/sour cream}        0.001136060
# [569]  {whipped/sour cream}          => {margarine}                 0.001136060
# [570]  {margarine}                   => {bottled beer}              0.001069233
# [571]  {bottled beer}                => {margarine}                 0.001069233
# [572]  {margarine}                   => {canned beer}               0.001202887
# [573]  {canned beer}                 => {margarine}                 0.001202887
# [574]  {margarine}                   => {shopping bags}             0.001002406
# [575]  {shopping bags}               => {margarine}                 0.001002406
# [576]  {margarine}                   => {pip fruit}                 0.001269714
# [577]  {pip fruit}                   => {margarine}                 0.001269714
# [578]  {margarine}                   => {pastry}                    0.001336541
# [579]  {pastry}                      => {margarine}                 0.001336541
# [580]  {margarine}                   => {citrus fruit}              0.001136060
# [581]  {citrus fruit}                => {margarine}                 0.001136060
# [582]  {margarine}                   => {bottled water}             0.001403368
# [583]  {bottled water}               => {margarine}                 0.001403368
# [584]  {margarine}                   => {sausage}                   0.001871157
# [585]  {sausage}                     => {margarine}                 0.001871157
# [586]  {margarine}                   => {root vegetables}           0.001937984
# [587]  {root vegetables}             => {margarine}                 0.001937984
# [588]  {margarine}                   => {tropical fruit}            0.001470195
# [589]  {tropical fruit}              => {margarine}                 0.001470195
# [590]  {margarine}                   => {yogurt}                    0.002138466
# [591]  {yogurt}                      => {margarine}                 0.002138466
# [592]  {margarine}                   => {soda}                      0.002606255
# [593]  {soda}                        => {margarine}                 0.002606255
# [594]  {margarine}                   => {rolls/buns}                0.003007217
# [595]  {rolls/buns}                  => {margarine}                 0.003007217
# [596]  {margarine}                   => {other vegetables}          0.003207698
# [597]  {other vegetables}            => {margarine}                 0.003207698
# [598]  {margarine}                   => {whole milk}                0.004076450
# [599]  {whole milk}                  => {margarine}                 0.004076450
# ...
# [840]  0.03552398 0.037623630 0.5106444  20
# [841]  0.01921230 0.069566961 0.5106444  20
# [842]  0.03907638 0.037623630 0.5766656  22
# [843]  0.02169625 0.067762630 0.5766656  22
# [844]  0.06216696 0.037623630 0.7239427  35
# [845]  0.02723735 0.085872761 0.7239427  35
# [846]  0.07637655 0.037623630 0.7865786  43
# [847]  0.02959394 0.097099706 0.7865786  43
# [848]  0.08880995 0.037623630 0.8073828  50
# [849]  0.03037667 0.109997327 0.8073828  50
# [850]  0.08170515 0.037623630 0.6692041  46
# [851]  0.02517789 0.122093023 0.6692041  46
# [852]  0.11900533 0.037623630 0.7536165  67
# [853]  0.02835379 0.157912323 0.7536165  67
# [854]  0.02749141 0.038893344 0.7281087  16
# [855]  0.02831858 0.037757284 0.7281087  16
# [856]  0.03951890 0.038893344 0.9042214  23
# [857]  0.03516820 0.043704892 0.9042214  23
# [858]  0.04467354 0.038893344 0.9859806  26
# [859]  0.03834808 0.045308741 0.9859806  26
# [860]  0.04810997 0.038893344 1.0255235  28
# [861]  0.03988604 0.046912590 1.0255235  28
# [862]  0.04639175 0.038893344 0.9750087  27
# [863]  0.03792135 0.047580861 0.9750087  27
# [864]  0.03264605 0.038893344 0.6655524  19
# [865]  0.02588556 0.049051056 0.6655524  19
# [866]  0.05154639 0.038893344 0.9965636  30
# [867]  0.03875969 0.051724138 0.9965636  30
# [868]  0.03092784 0.038893344 0.5821436  18
# [869]  0.02264151 0.053127506 0.5821436  18
# [870]  0.04639175 0.038893344 0.7645443  27
# [871]  0.02973568 0.060678963 0.7645443  27
# [872]  0.04639175 0.038893344 0.7687776  27
# [873]  0.02990033 0.060344828 0.7687776  27
# [874]  0.06529210 0.038893344 0.9385504  38
# [875]  0.03650336 0.069566961 0.9385504  38
# [876]  0.04810997 0.038893344 0.7099778  28
# [877]  0.02761341 0.067762630 0.7099778  28
# [878]  0.07388316 0.038893344 0.8603795  43
# [879]  0.03346304 0.085872761 0.8603795  43
# [880]  0.06013746 0.038893344 0.6193372  35
# [881]  0.02408809 0.097099706 0.6193372  35
# [882]  0.07731959 0.038893344 0.7029224  45
# [883]  0.02733900 0.109997327 0.7029224  45
# [884]  0.09450172 0.038893344 0.7740141  55
# [885]  0.03010400 0.122093023 0.7740141  55
# [886]  0.14432990 0.038893344 0.9139875  84
# [887]  0.03554803 0.157912323 0.9139875  84
# [888]  0.03893805 0.037757284 0.8909312  22
# [889]  0.03363914 0.043704892 0.8909312  22
# [890]  0.04424779 0.037757284 0.9765839  25
# [891]  0.03687316 0.045308741 0.9765839  25
# [892]  0.03539823 0.037757284 0.7545571  20
# [893]  0.02849003 0.046912590 0.7545571  20
# [894]  0.04070796 0.037757284 0.8555533  23
# [895]  0.03230337 0.047580861 0.8555533  23
# [896]  0.04778761 0.037757284 0.9742422  27
# [897]  0.03678474 0.049051056 0.9742422  27
# [898]  0.04601770 0.037757284 0.8896755  26
# [899]  0.03359173 0.051724138 0.8896755  26
# [900]  0.04601770 0.037757284 0.8661747  26
# [901]  0.03270440 0.053127506 0.8661747  26
# [902]  0.05840708 0.037757284 0.9625590  33
# [903]  0.03634361 0.060678963 0.9625590  33
# [904]  0.03893805 0.037757284 0.6452592  22
# [905]  0.02436323 0.060344828 0.6452592  22
# [906]  0.05840708 0.037757284 0.8395807  33
# [907]  0.03170029 0.069566961 0.8395807  33
# [908]  0.03539823 0.037757284 0.5223857  20
# [909]  0.01972387 0.067762630 0.5223857  20
# [910]  0.06725664 0.037757284 0.7832127  38
# [911]  0.02957198 0.085872761 0.7832127  38
# [912]  0.08141593 0.037757284 0.8384776  46
# [913]  0.03165864 0.097099706 0.8384776  46
# [914]  0.09734513 0.037757284 0.8849773  55
# [915]  0.03341434 0.109997327 0.8849773  55
# [916]  0.13628319 0.037757284 1.1162242  77
# [917]  0.04214559 0.122093023 1.1162242  77
# [918]  0.13982301 0.037757284 0.8854471  79
# [919]  0.03343208 0.157912323 0.8854471  79
# [920]  0.02752294 0.043704892 0.6074531  18
# [921]  0.02654867 0.045308741 0.6074531  18
# [922]  0.03516820 0.043704892 0.7496537  23
# [923]  0.03276353 0.046912590 0.7496537  23
# [924]  0.02752294 0.043704892 0.5784455  18
# [925]  0.02528090 0.047580861 0.5784455  18
# [926]  0.03822630 0.043704892 0.7793166  25
# [927]  0.03405995 0.049051056 0.7793166  25
# [928]  0.03516820 0.043704892 0.6799185  23
# [929]  0.02971576 0.051724138 0.6799185  23
# [930]  0.04740061 0.043704892 0.8922047  31
# [931]  0.03899371 0.053127506 0.8922047  31
# [932]  0.04128440 0.043704892 0.6803742  27
# [933]  0.02973568 0.060678963 0.6803742  27
# [934]  0.04892966 0.043704892 0.8108344  32
# [935]  0.03543743 0.060344828 0.8108344  32
# [936]  0.05657492 0.043704892 0.8132441  37
# [937]  0.03554275 0.069566961 0.8132441  37
# [938]  0.05657492 0.043704892 0.8348986  37
# [939]  0.03648915 0.067762630 0.8348986  37
# [940]  0.06727829 0.043704892 0.7834648  44
# [941]  0.03424125 0.085872761 0.7834648  44
# [942]  0.07798165 0.043704892 0.8031090  51
# [943]  0.03509979 0.097099706 0.8031090  51
# [944]  0.06727829 0.043704892 0.6116357  44
# [945]  0.02673147 0.109997327 0.6116357  44
# [946]  0.09480122 0.043704892 0.7764672  62
# [947]  0.03393541 0.122093023 0.7764672  62
# [948]  0.10550459 0.043704892 0.6681213  69
# [949]  0.02920017 0.157912323 0.6681213  69
# [950]  0.04129794 0.045308741 0.8803167  28
# [951]  0.03988604 0.046912590 0.8803167  28
# [952]  0.03244838 0.045308741 0.6819628  22
# [953]  0.03089888 0.047580861 0.6819628  22
# [954]  0.03392330 0.045308741 0.6915917  23
# [955]  0.03133515 0.049051056 0.6915917  23
# [956]  0.04572271 0.045308741 0.8839725  31
# [957]  0.04005168 0.051724138 0.8839725  31
# [958]  0.03687316 0.045308741 0.6940502  25
# [959]  0.03144654 0.053127506 0.6940502  25
# [960]  0.05604720 0.045308741 0.9236677  38
# [961]  0.04185022 0.060678963 0.9236677  38
# [962]  0.07374631 0.045308741 1.2220818  50
# [963]  0.05537099 0.060344828 1.2220818  50
# [964]  0.05457227 0.045308741 0.7844567  37
# [965]  0.03554275 0.069566961 0.7844567  37
# [966]  0.05604720 0.045308741 0.8271107  38
# [967]  0.03747535 0.067762630 0.8271107  38
# [968]  0.07522124 0.045308741 0.8759616  51
# [969]  0.03968872 0.085872761 0.8759616  51
# [970]  0.06489676 0.045308741 0.6683517  44
# [971]  0.03028217 0.097099706 0.6683517  44
# [972]  0.08849558 0.045308741 0.8045248  60
# [973]  0.03645200 0.109997327 0.8045248  60
# [974]  0.10324484 0.045308741 0.8456244  70
# [975]  0.03831418 0.122093023 0.8456244  70
# [976]  0.15781711 0.045308741 0.9993970 107
# [977]  0.04528142 0.157912323 0.9993970 107
# [978]  0.03988604 0.046912590 0.8382791  28
# [979]  0.03932584 0.047580861 0.8382791  28
# [980]  0.03418803 0.046912590 0.6969888  24
# [981]  0.03269755 0.049051056 0.6969888  24
# [982]  0.03988604 0.046912590 0.7711301  28
# [983]  0.03617571 0.051724138 0.7711301  28
# [984]  0.03276353 0.046912590 0.6166962  23
# [985]  0.02893082 0.053127506 0.6166962  23
# [986]  0.03133903 0.046912590 0.5164728  22
# [987]  0.02422907 0.060678963 0.5164728  22
# [988]  0.05270655 0.046912590 0.8734229  37
# [989]  0.04097453 0.060344828 0.8734229  37
# [990]  0.04415954 0.046912590 0.6347775  31
# [991]  0.02977906 0.069566961 0.6347775  31
# [992]  0.05413105 0.046912590 0.7988334  38
# [993]  0.03747535 0.067762630 0.7988334  38
# [994]  0.08262108 0.046912590 0.9621338  58
# [995]  0.04513619 0.085872761 0.9621338  58
# [996]  0.06695157 0.046912590 0.6895136  47
# [997]  0.03234687 0.097099706 0.6895136  47
# [998]  0.08974359 0.046912590 0.8158706  63
# [999]  0.03827461 0.109997327 0.8158706  63
# [1000] 0.08547009 0.046912590 0.7000407  60
# [1001] 0.03284072 0.122093023 0.7000407  60
# [1002] 0.12820513 0.046912590 0.8118754  90
# [1003] 0.03808718 0.157912323 0.8118754  90
# [1004] 0.03932584 0.047580861 0.8017328  28
# [1005] 0.03814714 0.049051056 0.8017328  28
# [1006] 0.02808989 0.047580861 0.5430712  20
# [1007] 0.02583979 0.051724138 0.5430712  20
# [1008] 0.03792135 0.047580861 0.7137799  27
# [1009] 0.03396226 0.053127506 0.7137799  27
# [1010] 0.04213483 0.047580861 0.6943894  30
# [1011] 0.03303965 0.060678963 0.6943894  30
# [1012] 0.04073034 0.047580861 0.6749599  29
# [1013] 0.03211517 0.060344828 0.6749599  29
# [1014] 0.07022472 0.047580861 1.0094550  50
# [1015] 0.04803074 0.069566961 1.0094550  50
# [1016] 0.05758427 0.047580861 0.8497939  41
# [1017] 0.04043393 0.067762630 0.8497939  41
# [1018] 0.07443820 0.047580861 0.8668430  53
# [1019] 0.04124514 0.085872761 0.8668430  53
# [1020] 0.09269663 0.047580861 0.9546541  66
# [1021] 0.04542326 0.097099706 0.9546541  66
# [1022] 0.09971910 0.047580861 0.9065593  71
# [1023] 0.04313487 0.109997327 0.9065593  71
# [1024] 0.10393258 0.047580861 0.8512574  74
# [1025] 0.04050356 0.122093023 0.8512574  74
# [1026] 0.13342697 0.047580861 0.8449433  95
# [1027] 0.04020313 0.157912323 0.8449433  95
# [1028] 0.04495913 0.049051056 0.8692098  33
# [1029] 0.04263566 0.051724138 0.8692098  33
# [1030] 0.02997275 0.049051056 0.5641664  22
# [1031] 0.02767296 0.053127506 0.5641664  22
# [1032] 0.04087193 0.049051056 0.6735767  30
# [1033] 0.03303965 0.060678963 0.6735767  30
# [1034] 0.04359673 0.049051056 0.7224601  32
# [1035] 0.03543743 0.060344828 0.7224601  32
# [1036] 0.05449591 0.049051056 0.7833591  40
# [1037] 0.03842459 0.069566961 0.7833591  40
# [1038] 0.04223433 0.049051056 0.6232688  31
# [1039] 0.03057199 0.067762630 0.6232688  31
# [1040] 0.07356948 0.049051056 0.8567266  54
# [1041] 0.04202335 0.085872761 0.8567266  54
# [1042] 0.08038147 0.049051056 0.8278240  59
# [1043] 0.04060564 0.097099706 0.8278240  59
# [1044] 0.10081744 0.049051056 0.9165444  74
# [1045] 0.04495747 0.109997327 0.9165444  74
# [1046] 0.10081744 0.049051056 0.8257428  74
# [1047] 0.04050356 0.122093023 0.8257428  74
# [1048] 0.13487738 0.049051056 0.8541283  99
# [1049] 0.04189590 0.157912323 0.8541283  99
# [1050] 0.04134367 0.051724138 0.7781971  32
# [1051] 0.04025157 0.053127506 0.7781971  32
# [1052] 0.05555556 0.051724138 0.9155653  43
# [1053] 0.04735683 0.060678963 0.9155653  43
# [1054] 0.06201550 0.051724138 1.0276855  48
# [1055] 0.05315615 0.060344828 1.0276855  48
# [1056] 0.05555556 0.051724138 0.7985911  43
# [1057] 0.04130644 0.069566961 0.7985911  43
# [1058] 0.05426357 0.051724138 0.8007890  42
# [1059] 0.04142012 0.067762630 0.8007890  42
# [1060] 0.06976744 0.051724138 0.8124514  54
# [1061] 0.04202335 0.085872761 0.8124514  54
# [1062] 0.07881137 0.051724138 0.8116540  61
# [1063] 0.04198211 0.097099706 0.8116540  61
# [1064] 0.07622739 0.051724138 0.6929931  59
# [1065] 0.03584447 0.109997327 0.6929931  59
# [1066] 0.07105943 0.051724138 0.5820106  55
# [1067] 0.03010400 0.122093023 0.5820106  55
# [1068] 0.12532300 0.051724138 0.7936239  97
# [1069] 0.04104951 0.157912323 0.7936239  97
# [1070] 0.04905660 0.053127506 0.8084615  39
# [1071] 0.04295154 0.060678963 0.8084615  39
# [1072] 0.02264151 0.053127506 0.3752022  18
# [1073] 0.01993355 0.060344828 0.3752022  18
# [1074] 0.04150943 0.053127506 0.5966832  33
# [1075] 0.03170029 0.069566961 0.5966832  33
# [1076] 0.05408805 0.053127506 0.7981988  43
# [1077] 0.04240631 0.067762630 0.7981988  43
# [1078] 0.08679245 0.053127506 1.0107099  69
# [1079] 0.05369650 0.085872761 1.0107099  69
# [1080] 0.07044025 0.053127506 0.7254425  56
# [1081] 0.03854095 0.097099706 0.7254425  56
# [1082] 0.08805031 0.053127506 0.8004769  70
# [1083] 0.04252734 0.109997327 0.8004769  70
# [1084] 0.09056604 0.053127506 0.7417790  72
# [1085] 0.03940887 0.122093023 0.7417790  72
# [1086] 0.13459119 0.053127506 0.8523160 107
# [1087] 0.04528142 0.157912323 0.8523160 107
# [1088] 0.05176211 0.060678963 0.8577722  47
# [1089] 0.05204873 0.060344828 0.8577722  47
# [1090] 0.05726872 0.060678963 0.8232173  52
# [1091] 0.04995197 0.069566961 0.8232173  52
# [1092] 0.05837004 0.060678963 0.8613899  53
# [1093] 0.05226824 0.067762630 0.8613899  53
# [1094] 0.06277533 0.060678963 0.7310273  57
# [1095] 0.04435798 0.085872761 0.7310273  57
# [1096] 0.07929515 0.060678963 0.8166364  72
# [1097] 0.04955265 0.097099706 0.8166364  72
# [1098] 0.07709251 0.060678963 0.7008580  70
# [1099] 0.04252734 0.109997327 0.7008580  70
# [1100] 0.09030837 0.060678963 0.7396686  82
# [1101] 0.04488232 0.122093023 0.7396686  82
# [1102] 0.11784141 0.060678963 0.7462458 107
# [1103] 0.04528142 0.157912323 0.7462458 107
# [1104] 0.05537099 0.060344828 0.7959380  50
# [1105] 0.04803074 0.069566961 0.7959380  50
# [1106] 0.05094131 0.060344828 0.7517611  46
# [1107] 0.04536489 0.067762630 0.7517611  46
# [1108] 0.09523810 0.060344828 1.1090606  86
# [1109] 0.06692607 0.085872761 1.1090606  86
# [1110] 0.09856035 0.060344828 1.0150428  89
# [1111] 0.06125258 0.097099706 1.0150428  89
# [1112] 0.08859358 0.060344828 0.8054157  80
# [1113] 0.04860267 0.109997327 0.8054157  80
# [1114] 0.09966777 0.060344828 0.8163265  90
# [1115] 0.04926108 0.122093023 0.8163265  90
# [1116] 0.14839424 0.060344828 0.9397255 134
# [1117] 0.05670758 0.157912323 0.9397255 134
# [1118] 0.05283381 0.069566961 0.7796895  55
# [1119] 0.05424063 0.067762630 0.7796895  55
# [1120] 0.06147935 0.069566961 0.7159354  64
# [1121] 0.04980545 0.085872761 0.7159354  64
# [1122] 0.07588857 0.069566961 0.7815530  79
# [1123] 0.05437027 0.097099706 0.7815530  79
# [1124] 0.08261287 0.069566961 0.7510444  86
# [1125] 0.05224787 0.109997327 0.7510444  86
# [1126] 0.07588857 0.069566961 0.6215635  79
# [1127] 0.04324028 0.122093023 0.6215635  79
# [1128] 0.10854947 0.069566961 0.6874034 113
# [1129] 0.04782057 0.157912323 0.6874034 113
# [1130] 0.07692308 0.067762630 0.8957797  78
# [1131] 0.06070039 0.085872761 0.8957797  78
# [1132] 0.07988166 0.067762630 0.8226766  81
# [1133] 0.05574673 0.097099706 0.8226766  81
# [1134] 0.08974359 0.067762630 0.8158706  91
# [1135] 0.05528554 0.109997327 0.8158706  91
# [1136] 0.09270217 0.067762630 0.7592749  94
# [1137] 0.05145047 0.122093023 0.7592749  94
# [1138] 0.12130178 0.067762630 0.7681590 123
# [1139] 0.05205248 0.157912323 0.7681590 123
# [1140] 0.06770428 0.085872761 0.6972656  87
# [1141] 0.05987612 0.097099706 0.6972656  87
# [1142] 0.09105058 0.085872761 0.8277527 117
# [1143] 0.07108141 0.109997327 0.8277527 117
# [1144] 0.09416342 0.085872761 0.7712433 121
# [1145] 0.06622879 0.122093023 0.7712433 121
# [1146] 0.12996109 0.085872761 0.8229952 167
# [1147] 0.07067287 0.157912323 0.8229952 167
# [1148] 0.08327598 0.097099706 0.7570728 121
# [1149] 0.07351154 0.109997327 0.7570728 121
# [1150] 0.09979353 0.097099706 0.8173565 145
# [1151] 0.07936508 0.122093023 0.8173565 145
# [1152] 0.11975224 0.097099706 0.7583464 174
# [1153] 0.07363521 0.157912323 0.7583464 174
# [1154] 0.09599028 0.109997327 0.7862061 158
# [1155] 0.08648057 0.122093023 0.7862061 158
# [1156] 0.12697448 0.109997327 0.8040822 209
# [1157] 0.08844689 0.157912323 0.8040822 209
# [1158] 0.12151067 0.122093023 0.7694819 222
# [1159] 0.09394837 0.157912323 0.7694819 222
# [1160] 0.25581395 0.005747126 1.6199746  22
# [1161] 0.16417910 0.008954825 1.9118880  22
# [1162] 0.13173653 0.011160118 2.1830624  22
# [1163] 0.17977528 0.005947608 1.1384500  16
# [1164] 0.11940299 0.008954825 1.2296946  16
# [1165] 0.09195402 0.011627907 1.5238095  16
# [1166] 0.21250000 0.005346164 1.3456835  17
# [1167] 0.12686567 0.008954825 1.1533523  17
# [1168] 0.08133971 0.013966854 1.3479152  17
# [1169] 0.17094017 0.007818765 1.0825005  20
# [1170] 0.11976048 0.011160118 1.0887581  20
# [1171] 0.09569378 0.013966854 1.1143671  20
# [1172] 0.14049587 0.008086073 0.8897081  17
# [1173] 0.10179641 0.011160118 0.8337610  17
# [1174] 0.07657658 0.014835605 0.8917447  17
# [1175] 0.14049587 0.008086073 1.1507281  17
# [1176] 0.11724138 0.009689922 1.0658566  17
# [1177] 0.10759494 0.010558674 1.1080872  17
# [1178] 0.12396694 0.008086073 0.7850365  15
# [1179] 0.08620690 0.011627907 0.7837181  15
# [1180] 0.07177033 0.013966854 0.7391406  15
# [1181] 0.11724138 0.009689922 0.7424460  17
# [1182] 0.09770115 0.011627907 0.8002189  17
# [1183] 0.07657658 0.014835605 0.7886386  17
# [1184] 0.11392405 0.010558674 0.7214386  18
# [1185] 0.08612440 0.013966854 0.7053999  18
# [1186] 0.08108108 0.014835605 0.7371186  18

# %%
# convert to dataframe and view

df_basket <- as(basket_rules, "data.frame")

df_basket$confidence <- df_basket$confidence * 100
df_basket$support <- df_basket$support * nrow(df)

# str(df_basket_1)

# not working but it said it was optional so oh well
# Out:
# Error in `$<-.data.frame`(`*tmp*`, support, value = numeric(0)): replacement has 0 rows, data has 1186
# Traceback:
#
# 1. `$<-`(`*tmp*`, support, value = numeric(0))
# 2. `$<-.data.frame`(`*tmp*`, support, value = numeric(0))
# 3. stop(sprintf(ngettext(N, "replacement has %d row, data has %d",
#  .     "replacement has %d rows, data has %d"), N, nrows), domain = NA)

# %%
# Mining rules for recommendations:

# split lhs and rhs into two columns
library(reshape2)

# %%
df_basket <- transform(df_basket, rules = colsplit(rules, pattern = "=>", names = c("lhs", "rhs")))

# remove curly brackets around rules
df_basket$rules$lhs <- gsub("[[punct:]]", "", df_basket$rules$lhs)
df_basket$rules$rhs <- gsub("[[punct:]]", "", df_basket$rules$rhs)

# convert to character
df_nbasket$rules$lhs <- as.character(df_basket$rules$lhs)
df_nbasket$rules$rhs <- as.character(df_basket$rules$rhs)

# also not working for same reason as above
# Out:
# Error in transform(df_basket, rules = colsplit(rules, pattern = "=>", : object 'df_basket' not found
# Traceback:
#
# 1. transform(df_basket, rules = colsplit(rules, pattern = "=>",
#  .     names = c("lhs", "rhs")))

# %%
library(stringi)
library(dplyr)
df_basket$rules %>%
  filter(stri_detect_fixed(lhs, "yogurt")) %>%
  select(rhs)

# not working again
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:arules':
#
#     intersect, recode, setdiff, setequal, union
#
#
# The following objects are masked from 'package:plyr':
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
# Error in UseMethod("filter"): no applicable method for 'filter' applied to an object of class "character"
# Traceback:
#
# 1. df_basket$rules %>% filter(stri_detect_fixed(lhs, "yogurt")) %>%
#  .     select(rhs)
# 2. select(., rhs)
# 3. filter(., stri_detect_fixed(lhs, "yogurt"))

# %%
# plot the rules
library(arulesViz)
plot(basket_rules)
# Out:
# To reduce overplotting, jitter is added! Use jitter = 0 to prevent jitter.
# plot without title

# %%
set.seed(8000)
plot(basket_rules, method = "grouped", control = list(k = 5))

plot(basket_rules[1:10,], method="graph", control=list(type="items"))

plot(basket_rules[1:10,], method="paracoord",  control=list(alpha=.5, reorder=TRUE))

itemFrequencyPlot(txn, topN = 5)

plot(basket_rules[1:10,],measure=c("support","lift"),shading="confidence",interactive=T)

# some of this didn't work but most of this is way over my head so I didn't worry too much about it
# Out:
# Warning message:
# "Unknown control parameters: type"
# Available control parameters (with default values):
# layout	 =  list(fun = function (graph, dim = 2, ...)  {     if ("layout" %in% graph_attr_names(graph)) {         lay <- graph_attr(graph, "layout")         if (is.function(lay)) {             lay(graph, ...)         }         else {             lay         }     }     else if (all(c("x", "y") %in% vertex_attr_names(graph))) {         if ("z" %in% vertex_attr_names(graph)) {             cbind(V(graph)$x, V(graph)$y, V(graph)$z)         }         else {             cbind(V(graph)$x, V(graph)$y)         }     }     else if (vcount(graph) < 1000) {         layout_with_fr(graph, dim = dim, ...)     }     else {         layout_with_drl(graph, dim = dim, ...)     } }, call_str = "layout_nicely(<graph>, )", args = list())
# edges	 =  <environment>
# nodes	 =  <environment>
# nodetext	 =  <environment>
# colors	 =  c("#EE0000FF", "#EEEEEEFF")
# engine	 =  ggplot2
# max	 =  100
# verbose	 =  FALSE
# plot without title
# plot without title
# plot without title
# Warning message in plot.rules(basket_rules[1:10, ], measure = c("support", "lift"), :
# "The parameter interactive is deprecated. Use engine='interactive' instead."
# To reduce overplotting, jitter is added! Use jitter = 0 to prevent jitter.
# Interactive mode.
# Select a region with two clicks!
# Error in upgradeUnit.default(x): Not a unit object
# Traceback:
#
# 1. plot(basket_rules[1:10, ], measure = c("support", "lift"), shading = "confidence",
#  .     interactive = T)
# 2. plot.rules(basket_rules[1:10, ], measure = c("support", "lift"),
#  .     shading = "confidence", interactive = T)
# 3. scatterplot(x, measure = measure, shading = shading, control,
#  .     ...)
# 4. scatterplot_grid(x, measure = measure, shading = shading, control = control,
#  .     ...)
# 5. gGetEvent(gI)
# 6. whichButton(gI, location)
# 7. convertX(location$x, "npc", valueOnly = TRUE)
# 8. convertUnit(x, unitTo, "x", "location", "x", "location", valueOnly = valueOnly)
# 9. upgradeUnit(x)
# 10. upgradeUnit.default(x)
# 11. stop("Not a unit object")
# plot without title
# plot without title
